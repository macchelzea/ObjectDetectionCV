# %%
import cv2

cap = cv2.VideoCapture(0)
print("Camera opened:", cap.isOpened())

ret, frame = cap.read()
print("Frame captured:", ret)

cap.release()
# Out:
# Camera opened: False
# Frame captured: False
# [ WARN:0@0.041] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@0.041] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
